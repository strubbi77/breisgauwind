# %%
import osmnx as ox
# get the building footprints in Macclesfield
place = "Landkreis Breisgau-Hochschwarzwald"
#tags = {'building': 'school'}
# Ebene Landkreis
tags = {'admin_level': '6'}
#gdf = ox.geometries_from_place(place, tags)

#tags = {'boundary': 'administrative'}   

bh_osmid='R1946367'
lk_bh=ox.geocode_to_gdf(bh_osmid, by_osmid=True)
lk_bh_poly=lk_bh.geometry[0]

# %%
lk_bh.plot()
# Out:
# <Axes: >

# %%
# Ebene Gemeinde
tags = {'admin_level': '8'}
gdf =ox.features.features_from_polygon(lk_bh_poly,tags)

# %%
in_bh=gdf.within(lk_bh_poly)

# %%
gem_in_bh_gdf=gdf[in_bh & (gdf['name'].notnull()) & (gdf['type'] == 'boundary') ]

# %%
import json
with open('schulen.json') as f:
    x = json.load(f)

#sc=json.read_file('schulen.json')
#x = json.loads(sc)

# %%
#in_bh_gdf.plot()
tags = {'boundary': 'administrative'}
gem_bh_gdf =ox.features.features_from_polygon(lk_bh_poly,tags)

# %%
in_bh=gem_bh_gdf.within(lk_bh_poly)
ort_in_bh_gdf=gem_bh_gdf[in_bh & (gem_bh_gdf['name'].notnull()) & (gem_bh_gdf['type'] == 'boundary') & gem_bh_gdf['de:regionalschluessel'].isnull()]

# %%
# Ebene Ortsteil
tags = {'boundary': 'administrative'}
#bk=gem_in_bh_gdf[gem_in_bh_gdf['name']=='Bad Krozingen']
bk=gem_in_bh_gdf[gem_in_bh_gdf['name']=='Ehrenkirchen']

bk_ort =ox.features.features_from_polygon(bk.geometry[0],tags)
in_bk=bk_ort.within(bk.geometry[0])
ort_in_bk_gdf=bk_ort[in_bk & (bk_ort['name'].notnull()) & (bk_ort['type'] == 'boundary') & bk_ort['de:regionalschluessel'].isnull()]
# Out:
# C:\Users\tstrub\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\geopandas\geoseries.py:720: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   val = getattr(super(), mtd)(*args, **kwargs)
# C:\Users\tstrub\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\geopandas\geoseries.py:720: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   val = getattr(super(), mtd)(*args, **kwargs)

# %%
ort_in_bh_gdf
# Out:
#                                                                geometry  \
# element_type osmid
# relation     68452    POLYGON ((7.72741 47.94288, 7.72512 47.94628, ...
#              68453    POLYGON ((7.71759 47.94234, 7.71763 47.94235, ...
#              68458    POLYGON ((7.76723 47.92474, 7.76732 47.92476, ...
#              68460    POLYGON ((7.84037 47.92086, 7.84154 47.92111, ...
#              68467    POLYGON ((7.72214 47.90799, 7.7222 47.908, 7.7...
# ...                                                                 ...
#              1946222  MULTIPOLYGON (((7.7114 47.92558, 7.71138 47.92...
#              1954584  POLYGON ((7.78263 48.08025, 7.78266 48.08024, ...
#              1954585  POLYGON ((7.76757 48.04437, 7.76865 48.04656, ...
#              1954586  POLYGON ((7.74439 48.06466, 7.74446 48.06488, ...
#              1970193  MULTIPOLYGON (((7.85037 48.05136, 7.8504 48.05...
#
#                      source admin_level contact:website  \
# element_type osmid
# relation     68452      NaN           9             NaN
#              68453      NaN           9             NaN
#              68458      NaN          10             NaN
#              68460      NaN          10             NaN
#              68467      NaN          10             NaN
# ...                     ...         ...             ...
#              1946222    NaN          10             NaN
#              1954584    NaN           9             NaN
#              1954585    NaN           9             NaN
#              1954586    NaN           9             NaN
#              1970193    NaN          10             NaN
#
#                                        name name:af name:am name:an name:ar  \
# element_type osmid
# relation     68452              Scherzingen     NaN     NaN     NaN     NaN
#              68453                Norsingen     NaN     NaN     NaN     NaN
#              68458    Bollschweil (Kernort)     NaN     NaN     NaN     NaN
#              68460               St. Ulrich     NaN     NaN     NaN     NaN
#              68467             Ehrenstetten     NaN     NaN     NaN     NaN
# ...                                     ...     ...     ...     ...     ...
#              1946222             Kirchhofen     NaN     NaN     NaN     NaN
#              1954584             Holzhausen     NaN     NaN     NaN     NaN
#              1954585             Hugstetten     NaN     NaN     NaN     NaN
#              1954586           Neuershausen     NaN     NaN     NaN     NaN
#              1970193           Gundelfingen     NaN     NaN     NaN     NaN
#
#                      name:arc  ... alt_name:zh-Hant euro_const name:ja-Hira  \
# element_type osmid             ...
# relation     68452        NaN  ...              NaN        NaN          NaN
#              68453        NaN  ...              NaN        NaN          NaN
#              68458        NaN  ...              NaN        NaN          NaN
#              68460        NaN  ...              NaN        NaN          NaN
#              68467        NaN  ...              NaN        NaN          NaN
# ...                       ...  ...              ...        ...          ...
#              1946222      NaN  ...              NaN        NaN          NaN
#              1954584      NaN  ...              NaN        NaN          NaN
#              1954585      NaN  ...              NaN        NaN          NaN
#              1954586      NaN  ...              NaN        NaN          NaN
#              1970193      NaN  ...              NaN        NaN          NaN
#
#                      name:sje official_name:ja short_name:ja  \
# element_type osmid
# relation     68452        NaN              NaN           NaN
#              68453        NaN              NaN           NaN
#              68458        NaN              NaN           NaN
#              68460        NaN              NaN           NaN
#              68467        NaN              NaN           NaN
# ...                       ...              ...           ...
#              1946222      NaN              NaN           NaN
#              1954584      NaN              NaN           NaN
#              1954585      NaN              NaN           NaN
#              1954586      NaN              NaN           NaN
#              1970193      NaN              NaN           NaN
#
#                      source:euro_const old_name:en old_name:eo old_name:ru
# element_type osmid
# relation     68452                 NaN         NaN         NaN         NaN
#              68453                 NaN         NaN         NaN         NaN
#              68458                 NaN         NaN         NaN         NaN
#              68460                 NaN         NaN         NaN         NaN
#              68467                 NaN         NaN         NaN         NaN
# ...                                ...         ...         ...         ...
#              1946222               NaN         NaN         NaN         NaN
#              1954584               NaN         NaN         NaN         NaN
#              1954585               NaN         NaN         NaN         NaN
#              1954586               NaN         NaN         NaN         NaN
#              1970193               NaN         NaN         NaN         NaN
#
# [113 rows x 449 columns]

# %%
ort_in_bh_gdf
# Out:
#                                                                geometry  \
# element_type osmid
# relation     68452    POLYGON ((7.72741 47.94288, 7.72512 47.94628, ...
#              68453    POLYGON ((7.71759 47.94234, 7.71763 47.94235, ...
#              68458    POLYGON ((7.76723 47.92474, 7.76732 47.92476, ...
#              68460    POLYGON ((7.84037 47.92086, 7.84154 47.92111, ...
#              68467    POLYGON ((7.72214 47.90799, 7.7222 47.908, 7.7...
# ...                                                                 ...
#              1946222  MULTIPOLYGON (((7.7114 47.92558, 7.71138 47.92...
#              1954584  POLYGON ((7.78263 48.08025, 7.78266 48.08024, ...
#              1954585  POLYGON ((7.76757 48.04437, 7.76865 48.04656, ...
#              1954586  POLYGON ((7.74439 48.06466, 7.74446 48.06488, ...
#              1970193  MULTIPOLYGON (((7.85037 48.05136, 7.8504 48.05...
#
#                      source admin_level contact:website  \
# element_type osmid
# relation     68452      NaN           9             NaN
#              68453      NaN           9             NaN
#              68458      NaN          10             NaN
#              68460      NaN          10             NaN
#              68467      NaN          10             NaN
# ...                     ...         ...             ...
#              1946222    NaN          10             NaN
#              1954584    NaN           9             NaN
#              1954585    NaN           9             NaN
#              1954586    NaN           9             NaN
#              1970193    NaN          10             NaN
#
#                                        name name:af name:am name:an name:ar  \
# element_type osmid
# relation     68452              Scherzingen     NaN     NaN     NaN     NaN
#              68453                Norsingen     NaN     NaN     NaN     NaN
#              68458    Bollschweil (Kernort)     NaN     NaN     NaN     NaN
#              68460               St. Ulrich     NaN     NaN     NaN     NaN
#              68467             Ehrenstetten     NaN     NaN     NaN     NaN
# ...                                     ...     ...     ...     ...     ...
#              1946222             Kirchhofen     NaN     NaN     NaN     NaN
#              1954584             Holzhausen     NaN     NaN     NaN     NaN
#              1954585             Hugstetten     NaN     NaN     NaN     NaN
#              1954586           Neuershausen     NaN     NaN     NaN     NaN
#              1970193           Gundelfingen     NaN     NaN     NaN     NaN
#
#                      name:arc  ... alt_name:zh-Hant euro_const name:ja-Hira  \
# element_type osmid             ...
# relation     68452        NaN  ...              NaN        NaN          NaN
#              68453        NaN  ...              NaN        NaN          NaN
#              68458        NaN  ...              NaN        NaN          NaN
#              68460        NaN  ...              NaN        NaN          NaN
#              68467        NaN  ...              NaN        NaN          NaN
# ...                       ...  ...              ...        ...          ...
#              1946222      NaN  ...              NaN        NaN          NaN
#              1954584      NaN  ...              NaN        NaN          NaN
#              1954585      NaN  ...              NaN        NaN          NaN
#              1954586      NaN  ...              NaN        NaN          NaN
#              1970193      NaN  ...              NaN        NaN          NaN
#
#                      name:sje official_name:ja short_name:ja  \
# element_type osmid
# relation     68452        NaN              NaN           NaN
#              68453        NaN              NaN           NaN
#              68458        NaN              NaN           NaN
#              68460        NaN              NaN           NaN
#              68467        NaN              NaN           NaN
# ...                       ...              ...           ...
#              1946222      NaN              NaN           NaN
#              1954584      NaN              NaN           NaN
#              1954585      NaN              NaN           NaN
#              1954586      NaN              NaN           NaN
#              1970193      NaN              NaN           NaN
#
#                      source:euro_const old_name:en old_name:eo old_name:ru
# element_type osmid
# relation     68452                 NaN         NaN         NaN         NaN
#              68453                 NaN         NaN         NaN         NaN
#              68458                 NaN         NaN         NaN         NaN
#              68460                 NaN         NaN         NaN         NaN
#              68467                 NaN         NaN         NaN         NaN
# ...                                ...         ...         ...         ...
#              1946222               NaN         NaN         NaN         NaN
#              1954584               NaN         NaN         NaN         NaN
#              1954585               NaN         NaN         NaN         NaN
#              1954586               NaN         NaN         NaN         NaN
#              1970193               NaN         NaN         NaN         NaN
#
# [113 rows x 449 columns]

# %%
network_type = "walk"
trip_times = [5, 10, 15, 20, 25,30,40]  # in minutes
travel_speed = 3  # walking speed in km/hour
tags = {'building': True}   

# get one color for each isochrone
iso_colors = ox.plot.get_colors(n=len(trip_times), cmap="plasma", start=0)

lk_bh_walk=ox.graph_from_polygon(lk_bh_poly,network_type=network_type)
lk_bh_build=ox.features_from_polygon(lk_bh_poly,tags)

# %%
# add an edge attribute for time in minutes required to traverse each edge
meters_per_minute = travel_speed * 1000 / 60  # km per hour to m per minute
for _, _, _, data in lk_bh_walk.edges(data=True, keys=True):
    data["time"] = data["length"] / meters_per_minute

# %%
eki_buildings=ox.truncate.truncate_graph_polygon(lk_bh_build,poly)
figure, axes = ox.plot_graph(
    G,
    ax=axe,
    node_color=nc,
    node_size=ns,
    node_alpha=0.8,
    edge_linewidth=0.2,
    edge_color="#999999",
    show=False, 
    close=False
)

# %%
import networkx as nx
from shapely.geometry import Point

br=2
anz=25
fig, axs = plt.subplots(anz,br,figsize=(30, 120))
sw=0

#roads=lk_bh_walk
for index, row in gem_in_bh_gdf.iterrows():
    node_colors = {}
    poly_gem = gpd.GeoSeries(row['geometry'])
    axs[sw//br,sw%br].set_title(row['name'])

    for cur in (x["schools"]):
        p=Point(cur["lng"],cur["lat"])
        if p.within(poly_gem).any(): 
            poi=ox.distance.nearest_nodes(roads, cur["lng"],cur["lat"])
            for trip_time, color in zip(sorted(trip_times, reverse=True), iso_colors):
                subgraph = nx.ego_graph(roads, poi, radius=trip_time, distance="time")
                for node in subgraph.nodes():
                    col_old=0
                    if node in node_colors:
                        col_old=sum(node_colors[node])
                    if sum(color)>col_old:
                        node_colors[node] = color
    
    for idx_orte, row_orte in ort_in_bh_gdf.iterrows():
        poly_ort=row_orte['geometry']
        poly_ort = gpd.GeoSeries(row_orte['geometry'])
        p_center=poly_ort.centroid
        if poly_gem.contains(p_center).any():
            poly_ort.plot(ax=axs[sw//br,sw%br],facecolor='none', edgecolor='green')
            axs[sw//br,sw%br].annotate(text=row_orte["name"], xy=(p_center[0].x,p_center[0].y), horizontalalignment='center')
    lk_bh_build.plot(ax=axs[sw//br,sw%br],color='brown')
    nc = [node_colors[node] if node in node_colors else "none" for node in roads.nodes()]
    ns = [15 if node in node_colors else 0 for node in roads.nodes()]
    poly_gem.plot(ax=axs[sw//br,sw%br],facecolor='none', edgecolor='green')
    fig, ax = ox.plot_graph(
        roads,
        ax=axs[sw//br,sw%br],
        node_color=nc,
        node_size=ns,
        node_alpha=0.8,
        edge_linewidth=0.2,
        edge_color="#999999",
        show=False, 
        close=False
    )
    
    axs[sw//br,sw%br].set_ylim(poly_gem.bounds["miny"][0],poly_gem.bounds["maxy"][0])
    axs[sw//br,sw%br].set_xlim(poly_gem.bounds["minx"][0],poly_gem.bounds["maxx"][0])
    sw+=1
    if sw>3:
        break
plt.show()

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
import shapely
from shapely import LineString, MultiPoint, Polygon, Point, MultiPolygon
br=2
anz=25
fig, axs = plt.subplots(anz,br,figsize=(30, 120))
sw=0
for index, row in gem_in_bh_gdf.iterrows():
    roads=lk_bh_walk
    if row['name'] == 'Ehrenkirchen':
        axs[sw//br,sw%br].set_title(row['name'])
        poly = gpd.GeoSeries(row['geometry'])
        #for idx_build, row_build in lk_bh_build.iterrows():
        #    poly_build=gpd.GeoSeries(row_build['geometry'])
        #    if poly.contains(poly_build.centroid).any():
        #        poly_build.plot(ax=axs[sw//br,sw%br],color='brown')
        #for idx_orte, row_orte in ort_in_bh_gdf.iterrows():
        #    poly_ort=row_orte['geometry']
        #    poly_ort = gpd.GeoSeries(row_orte['geometry'])
        #    p_center=poly_ort.centroid
        #    if poly.contains(p_center).any():
        #        poly_ort.plot(ax=axs[sw//br,sw%br],color='white', edgecolor='green')
        #        axs[sw//br,sw%br].annotate(text=row_orte["name"], xy=(p_center[0].x,p_center[0].y), horizontalalignment='center')
        
        roads=ox.truncate.truncate_graph_polygon(lk_bh_walk,poly)
        fig, ax = ox.plot_graph(
            roads,
            ax=axs[sw//br,sw%br],
            node_color=nc,
            node_size=ns,
            node_alpha=0.8,
            edge_linewidth=0.2,
            edge_color="#999999",
            show=False, 
            close=False
        )        

        
        poly.plot(ax=axs[sw//br,sw%br],facecolor='none', edgecolor='black')
        
        sw+=1
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       8 fig, axs = plt.subplots(anz,br,figsize=(30, 120))
#       9 sw=0
# ---> 10 for index, row in gem_in_bh_gdf.iterrows():
#      11     roads=lk_bh_walk
#      12     if row['name'] == 'Ehrenkirchen':
#
# NameError: name 'gem_in_bh_gdf' is not defined

# %%
type(lk_bh_build)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
lk_bh_build.within(poly_gdf)
# Out:
# C:\Users\tstrub\AppData\Local\Temp\ipykernel_26008\3600892247.py:1: UserWarning: The indices of the left and right GeoSeries' are not equal, and therefore they will be aligned (reordering and/or introducing missing values) before executing the operation. If this alignment is the desired behaviour, you can silence this warning by passing 'align=True'. If you don't want alignment and protect yourself of accidentally aligning, you can pass 'align=False'.
#   lk_bh_build.within(poly_gdf)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 lk_bh_build.within(poly_gdf)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\geopandas\base.py:3441, in GeoPandasBase.within(self, other, align)
#    3329 def within(self, other, align=None):
#    3330     """Returns a ``Series`` of ``dtype('bool')`` with value ``True`` for
#    3331     each aligned geometry that is within `other`.
#    3332
#    (...)
#    3439     GeoSeries.contains
#    3440     """
# -> 3441     return _binary_op("within", self, other, align)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\geopandas\base.py:76, in _binary_op(op, this, other, align, *args, **kwargs)
#      73 def _binary_op(op, this, other, align, *args, **kwargs):
#      74     # type: (str, GeoSeries, GeoSeries, args/kwargs) -> Series[bool/float]
#      75     """Binary operation on GeoSeries objects that returns a Series"""
# ---> 76     data, index = _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      77     return Series(data, index=index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\geopandas\base.py:49, in _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      39     if maybe_warn:
#      40         warn(
#      41             "The indices of the left and right GeoSeries' are not equal, and "
#      42             "therefore they will be aligned (reordering and/or introducing "
#    (...)
#      47             stacklevel=4,
#      48         )
# ---> 49     this, other = this.align(other.geometry)
#      50 else:
#      51     other = other.geometry
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:10091, in NDFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#   10078     left, _right, join_index = self._align_frame(
#   10079         other,
#   10080         join=join,
#    (...)
#   10087         fill_axis=fill_axis,
#   10088     )
#   10090 elif isinstance(other, ABCSeries):
# > 10091     left, _right, join_index = self._align_series(
#   10092         other,
#   10093         join=join,
#   10094         axis=axis,
#   10095         level=level,
#   10096         copy=copy,
#   10097         fill_value=fill_value,
#   10098         method=method,
#   10099         limit=limit,
#   10100         fill_axis=fill_axis,
#   10101     )
#   10102 else:  # pragma: no cover
#   10103     raise TypeError(f"unsupported type: {type(other)}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:10208, in NDFrame._align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#   10206     join_index, lidx, ridx = None, None, None
#   10207 else:
# > 10208     join_index, lidx, ridx = self.index.join(
#   10209         other.index, how=join, level=level, return_indexers=True
#   10210     )
#   10212 if is_series:
#   10213     left = self._reindex_indexer(join_index, lidx, copy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:266, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     256 @functools.wraps(meth)
#     257 def join(
#     258     self,
#    (...)
#     264     sort: bool = False,
#     265 ):
# --> 266     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     267     if not return_indexers:
#     268         return join_index
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:4621, in Index.join(self, other, how, level, return_indexers, sort)
#    4619         pass
#    4620     else:
# -> 4621         return self._join_multi(other, how=how)
#    4623 # join on the level
#    4624 if level is not None and (self._is_multi or other._is_multi):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:4744, in Index._join_multi(self, other, how)
#    4742 # need at least 1 in common
#    4743 if not overlap:
# -> 4744     raise ValueError("cannot join with no overlapping index names")
#    4746 if isinstance(self, MultiIndex) and isinstance(other, MultiIndex):
#    4747     # Drop the non-matching levels from left and right respectively
#    4748     ldrop_names = sorted(self_names - overlap, key=self_names_order)
#
# ValueError: cannot join with no overlapping index names

# %%
dir(p_center)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 dir(p_center)
#
# NameError: name 'p_center' is not defined

# %%
p_center[0].x

# %%
type(roads)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
#roads=ox.truncate.truncate_graph_bbox(lk_bh_walk,bbox=(poly.bounds["minx"][0],poly.bounds["miny"][0],poly.bounds["maxx"][0],poly.bounds["maxy"][0]),truncate_by_edge=False,retain_all=True)
#roads=ox.truncate.truncate_graph_bbox(lk_bh_walk,bbox=(7.4,48,7.8,48.1),truncate_by_edge=False,retain_all=True)
roads=ox.truncate.truncate_graph_polygon(lk_bh_walk,poly)
node_colors = {}
nc = [node_colors[node] if node in node_colors else "none" for node in roads.nodes()]
ns = [15 if node in node_colors else 0 for node in roads.nodes()]
fig, ax = ox.plot_graph(
    roads,
    node_color=nc,
    node_size=ns,
    node_alpha=0.8,
    edge_linewidth=0.2,
    edge_color="#999999",
    show=False, 
    close=False
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16448\1882119380.py in ?()
#       1 #roads=ox.truncate.truncate_graph_bbox(lk_bh_walk,bbox=(poly.bounds["minx"][0],poly.bounds["miny"][0],poly.bounds["maxx"][0],poly.bounds["maxy"][0]),truncate_by_edge=False,retain_all=True)
#       2 #roads=ox.truncate.truncate_graph_bbox(lk_bh_walk,bbox=(7.4,48,7.8,48.1),truncate_by_edge=False,retain_all=True)
# ----> 3 roads=ox.truncate.truncate_graph_polygon(lk_bh_walk,poly)
#       4 node_colors = {}
#       5 nc = [node_colors[node] if node in node_colors else "none" for node in roads.nodes()]
#       6 ns = [15 if node in node_colors else 0 for node in roads.nodes()]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\osmnx\truncate.py in ?(G, polygon, retain_all, truncate_by_edge, quadrat_width, min_num)
#     167     utils.log("Identifying all nodes that lie outside the polygon...")
#     168
#     169     # first identify all nodes whose point geometries lie within the polygon
#     170     gs_nodes = convert.graph_to_gdfs(G, edges=False)[["geometry"]]
# --> 171     to_keep = utils_geo._intersect_index_quadrats(gs_nodes, polygon)
#     172
#     173     if not to_keep:
#     174         # no graph nodes within the polygon: can't create a graph from that
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\osmnx\utils_geo.py in ?(geometries, polygon)
#     367
#     368     # cut polygon into chunks for faster spatial index intersecting. specify a
#     369     # sensible quadrat_width to balance performance (eg, 0.1 degrees is approx
#     370     # 8 km at NYC's latitude) with either projected or unprojected coordinates
# --> 371     quadrat_width = max(0.1, np.sqrt(polygon.area) / 10)
#     372     multipoly = _quadrat_cut_geometry(polygon, quadrat_width)
#     373     utils.log(f"Accelerating r-tree with {len(multipoly.geoms)} quadrats")
#     374
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
(roads.size(),lk_bh_walk.size())
# Out:
# (67870, 210668)

# %%
(poly.bounds["minx"][0],poly.bounds["miny"][0],poly.bounds["maxx"][0],poly.bounds["maxy"][0])
# Out:
# (7.6112185, 48.0284124, 7.7075655, 48.0845314)

# %%
build_tr=lk_bh_build.within(poly)
# Out:
# C:\Users\tstrub\AppData\Local\Temp\ipykernel_16448\1811703555.py:1: UserWarning: The indices of the left and right GeoSeries' are not equal, and therefore they will be aligned (reordering and/or introducing missing values) before executing the operation. If this alignment is the desired behaviour, you can silence this warning by passing 'align=True'. If you don't want alignment and protect yourself of accidentally aligning, you can pass 'align=False'.
#   build_tr=lk_bh_build.within(poly)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 build_tr=lk_bh_build.within(poly)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\geopandas\base.py:3441, in GeoPandasBase.within(self, other, align)
#    3329 def within(self, other, align=None):
#    3330     """Returns a ``Series`` of ``dtype('bool')`` with value ``True`` for
#    3331     each aligned geometry that is within `other`.
#    3332
#    (...)
#    3439     GeoSeries.contains
#    3440     """
# -> 3441     return _binary_op("within", self, other, align)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\geopandas\base.py:76, in _binary_op(op, this, other, align, *args, **kwargs)
#      73 def _binary_op(op, this, other, align, *args, **kwargs):
#      74     # type: (str, GeoSeries, GeoSeries, args/kwargs) -> Series[bool/float]
#      75     """Binary operation on GeoSeries objects that returns a Series"""
# ---> 76     data, index = _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      77     return Series(data, index=index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\geopandas\base.py:49, in _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      39     if maybe_warn:
#      40         warn(
#      41             "The indices of the left and right GeoSeries' are not equal, and "
#      42             "therefore they will be aligned (reordering and/or introducing "
#    (...)
#      47             stacklevel=4,
#      48         )
# ---> 49     this, other = this.align(other.geometry)
#      50 else:
#      51     other = other.geometry
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:10091, in NDFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#   10078     left, _right, join_index = self._align_frame(
#   10079         other,
#   10080         join=join,
#    (...)
#   10087         fill_axis=fill_axis,
#   10088     )
#   10090 elif isinstance(other, ABCSeries):
# > 10091     left, _right, join_index = self._align_series(
#   10092         other,
#   10093         join=join,
#   10094         axis=axis,
#   10095         level=level,
#   10096         copy=copy,
#   10097         fill_value=fill_value,
#   10098         method=method,
#   10099         limit=limit,
#   10100         fill_axis=fill_axis,
#   10101     )
#   10102 else:  # pragma: no cover
#   10103     raise TypeError(f"unsupported type: {type(other)}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:10208, in NDFrame._align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#   10206     join_index, lidx, ridx = None, None, None
#   10207 else:
# > 10208     join_index, lidx, ridx = self.index.join(
#   10209         other.index, how=join, level=level, return_indexers=True
#   10210     )
#   10212 if is_series:
#   10213     left = self._reindex_indexer(join_index, lidx, copy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:266, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     256 @functools.wraps(meth)
#     257 def join(
#     258     self,
#    (...)
#     264     sort: bool = False,
#     265 ):
# --> 266     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     267     if not return_indexers:
#     268         return join_index
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:4621, in Index.join(self, other, how, level, return_indexers, sort)
#    4619         pass
#    4620     else:
# -> 4621         return self._join_multi(other, how=how)
#    4623 # join on the level
#    4624 if level is not None and (self._is_multi or other._is_multi):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:4744, in Index._join_multi(self, other, how)
#    4742 # need at least 1 in common
#    4743 if not overlap:
# -> 4744     raise ValueError("cannot join with no overlapping index names")
#    4746 if isinstance(self, MultiIndex) and isinstance(other, MultiIndex):
#    4747     # Drop the non-matching levels from left and right respectively
#    4748     ldrop_names = sorted(self_names - overlap, key=self_names_order)
#
# ValueError: cannot join with no overlapping index names

# %%
lk_bh_build
# Out:
#                        entrance  \
# element_type osmid
# node         290711483      NaN
#              291770511      NaN
#              302241673      NaN
#              311774360      NaN
#              313013688      NaN
# ...                         ...
# relation     13641767       NaN
#              13641768       NaN
#              14520585       NaN
#              16403955       NaN
#              17355420       NaN
#
#                                                                  geometry  \
# element_type osmid
# node         290711483                           POINT (7.68643 48.04852)
#              291770511                           POINT (8.03423 48.01718)
#              302241673                            POINT (8.10529 47.9058)
#              311774360                           POINT (8.00636 48.03735)
#              313013688                           POINT (8.02205 48.00574)
# ...                                                                   ...
# relation     13641767   POLYGON ((7.85583 47.94669, 7.85594 47.94671, ...
#              13641768   POLYGON ((7.85583 47.94669, 7.85594 47.94671, ...
#              14520585   POLYGON ((7.69948 47.90954, 7.69982 47.9093, 7...
#              16403955   MULTIPOLYGON (((7.8804 48.04553, 7.88045 48.04...
#              17355420   MULTIPOLYGON (((7.68965 47.91927, 7.68979 47.9...
#
#                        amenity  \
# element_type osmid
# node         290711483     NaN
#              291770511     NaN
#              302241673     NaN
#              311774360     NaN
#              313013688     NaN
# ...                        ...
# relation     13641767      NaN
#              13641768      NaN
#              14520585      NaN
#              16403955      NaN
#              17355420      NaN
#
#                                                               description  \
# element_type osmid
# node         290711483                                                NaN
#              291770511                                                NaN
#              302241673                     Hotelverzeichniss / hotel list
#              311774360                                                NaN
#              313013688                                                NaN
# ...                                                                   ...
# relation     13641767                                                 NaN
#              13641768                                                 NaN
#              14520585                                                 NaN
#              16403955   Naturkindergarten für 40 Kinder zwischen 3 und...
#              17355420                                                 NaN
#
#                                              operator operator:wikidata  \
# element_type osmid
# node         290711483                            NaN               NaN
#              291770511                            NaN               NaN
#              302241673                            NaN               NaN
#              311774360                            NaN               NaN
#              313013688                            NaN               NaN
# ...                                               ...               ...
# relation     13641767                             NaN               NaN
#              13641768                             NaN               NaN
#              14520585                             NaN               NaN
#              16403955   Jugendhilfswerk Freiburg e.V.               NaN
#              17355420                             NaN               NaN
#
#                               building                         name  \
# element_type osmid
# node         290711483          public                Drescheschopf
#              291770511          public                    Pfarrheim
#              302241673            roof                          NaN
#              311774360          chapel                 Türlekapelle
#              313013688  wayside_shrine                          NaN
# ...                                ...                          ...
# relation     13641767              yes                          NaN
#              13641768              yes                          NaN
#              14520585              yes             FC Bad Krozingen
#              16403955     kindergarten  Natur-Kita Lärchenstube JHW
#              17355420              yes                          NaN
#
#                        wheelchair board_type  ... lifeguard  \
# element_type osmid                            ...
# node         290711483        NaN        NaN  ...       NaN
#              291770511        yes        NaN  ...       NaN
#              302241673        yes     nature  ...       NaN
#              311774360        NaN        NaN  ...       NaN
#              313013688        NaN        NaN  ...       NaN
# ...                           ...        ...  ...       ...
# relation     13641767         NaN        NaN  ...       NaN
#              13641768         NaN        NaN  ...       NaN
#              14520585         NaN        NaN  ...       NaN
#              16403955         NaN        NaN  ...       NaN
#              17355420         NaN        NaN  ...       NaN
#
#                        disused:social_facility disused:social_facility:for  \
# element_type osmid
# node         290711483                     NaN                         NaN
#              291770511                     NaN                         NaN
#              302241673                     NaN                         NaN
#              311774360                     NaN                         NaN
#              313013688                     NaN                         NaN
# ...                                        ...                         ...
# relation     13641767                      NaN                         NaN
#              13641768                      NaN                         NaN
#              14520585                      NaN                         NaN
#              16403955                      NaN                         NaN
#              17355420                      NaN                         NaN
#
#                        capacity:disabled capacity:parent capacity:women  \
# element_type osmid
# node         290711483               NaN             NaN            NaN
#              291770511               NaN             NaN            NaN
#              302241673               NaN             NaN            NaN
#              311774360               NaN             NaN            NaN
#              313013688               NaN             NaN            NaN
# ...                                  ...             ...            ...
# relation     13641767                NaN             NaN            NaN
#              13641768                NaN             NaN            NaN
#              14520585                NaN             NaN            NaN
#              16403955                NaN             NaN            NaN
#              17355420                NaN             NaN            NaN
#
#                        parking:orientation building:shape house  \
# element_type osmid
# node         290711483                 NaN            NaN   NaN
#              291770511                 NaN            NaN   NaN
#              302241673                 NaN            NaN   NaN
#              311774360                 NaN            NaN   NaN
#              313013688                 NaN            NaN   NaN
# ...                                    ...            ...   ...
# relation     13641767                  NaN            NaN   NaN
#              13641768                  NaN            NaN   NaN
#              14520585                  NaN            NaN   NaN
#              16403955                  NaN            NaN   NaN
#              17355420                  NaN            NaN   NaN
#
#                                                                     ways
# element_type osmid
# node         290711483                                               NaN
#              291770511                                               NaN
#              302241673                                               NaN
#              311774360                                               NaN
#              313013688                                               NaN
# ...                                                                  ...
# relation     13641767   [1018773688, 1018773682, 1018773693, 1018773680]
#              13641768   [1018773688, 1018773682, 1018773681, 1018773680]
#              14520585                                         [37806841]
#              16403955               [1212117640, 1212117639, 1212117641]
#              17355420    [888748566, 1263473614, 1263473612, 1263473613]
#
# [151082 rows x 467 columns]
